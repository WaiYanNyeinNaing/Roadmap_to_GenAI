# %%
# !pip install vllm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 56.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 MB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 106.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 MB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 70.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 98.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Load LLM

# %%
from vllm import LLM, SamplingParams

# %%
llm = LLM(model="mistralai/Mistral-7B-Instruct-v0.1",trust_remote_code=True,dtype="auto")
# Out:
# INFO 12-16 23:21:12 llm_engine.py:73] Initializing an LLM engine with config: model='mistralai/Mistral-7B-Instruct-v0.1', tokenizer='mistralai/Mistral-7B-Instruct-v0.1', tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=32768, download_dir=None, load_format=auto, tensor_parallel_size=1, quantization=None, seed=0)
# INFO 12-16 23:21:23 llm_engine.py:222] # GPU blocks: 8921, # CPU blocks: 2048

# %% [markdown]
# # Information Extraction in Table Form

# %%
topic = """
2023: The State of Generative AI in the Enterprise
We surveyed more than 450 enterprise executives across the U.S. and Europe and spoke to a dozen more to provide a view into generative AI adoption in the enterprise today.
Enterprise spend: What do the numbers reveal? Prediction 1: Despite the hype, enterprise adoption of generative AI will be measured, like early cloud adoption
Prediction 2: The market will continue to favor incumbents who embed AI into existing product Prediction 3: Powerful context-aware, data-rich workflows will be the key to unlocking enterprise generative AI adoption
Three areas of opportunity where startups can win Vertical AI Horizontal AI The modern AI stack
For Menlo Ventures’ State of Generative AI in the Enterprise report, we surveyed more than 450 enterprise executives across the U.S. and Europe and spoke to a dozen more to provide a view into generative AI adoption in the enterprise today.
Despite the hype, our research revealed that enterprise investment in generative AI is still surprisingly small compared to other software categories. Most of the value that will be created remains to be seen. While incumbents dominate the market today, we’ve identified three areas of opportunity where startups have the best chances to win.
Below, we will dig into our research, sharing actual budget data and key findings to provide a view into how generative AI is perceived—and prioritized—by enterprise buyers.
Enterprise spend: What do the numbers reveal?
Enterprise investment in generative AI—which we estimate to be $2.5 billion this year—is surprisingly small compared to the enterprise budgets for traditional AI ($70 billion) and cloud software ($400 billion).
Graphic showing that GenAI spend is relatively small
Of course, AI is not new to the enterprise; traditional AI technologies (computer vision, deep learning, etc.) were in use long before generative AI emerged. Half of the enterprises we polled implemented some form of AI, whether into customer-facing products or for internal automation, prior to 2023.
The launch of ChatGPT marked a turning point: AI strategy suddenly became a hot topic in the boardroom. Adoption increased. After five years of stagnation, our survey found:
The number of enterprises using some form of AI ticked up 7% (from 48% in 2022 to 55% in 2023).
During that same period, AI spend within enterprises grew by an average of 8%. This ate into total enterprise tech spend, which only grew by 5%.
"""

# %%
sample_topic ="""
The Bosch Group is a leading global supplier of technology and services. It employs
roughly 421,300 associates worldwide (as of December 31, 2022). The company generated
sales of 88.2 billion euros in 2022. Its operations are divided into four business sectors:
Mobility Solutions, Industrial Technology, Consumer Goods, and Energy and Building
Technology. As a leading IoT provider, Bosch offers innovative solutions for smart homes,
Industry 4.0, and connected mobility. Bosch is pursuing a vision of mobility that is sustainable, safe, and exciting. It uses its expertise in sensor technology, software, and services,
as well as its own IoT cloud, to offer its customers connected, cross-domain solutions
from a single source.
"""

# %%
instruction = f"""
{sample_topic}
Generate a table containing this information:
Result:
| Mobility Solutions | Offers innovative solutions for connected and autonomous driving, as well as electric and hybrid vehicles. |
| Industrial Technology | Provides solutions for manufacturing, logistics, and supply chain management, as well as energy and building technology. |
| Consumer Goods | Offers a wide range of consumer products, including home appliances, power tools, and automotive aftermarket products. |
| Energy and Building Technology | Provides solutions for smart homes, energy efficiency, and building automation. |

{topic}
Result:
"""

# print(instruction)

# %%
sampling_params = SamplingParams(temperature=0.1, top_p=0.95,max_tokens=200)

# %%
outputs = llm.generate(instruction, sampling_params)

result = outputs[0].outputs[0].text
print(result)
print("")
# Out:
# Processed prompts: 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]
# | Enterprise Spend | AI is still surprisingly small compared to other software categories. Most of the value that will be created remains to be seen. |
# | AI Spend | Enterprise investment in generative AI is estimated to be $2.5 billion this year. |
# | Traditional AI Spend | Enterprise budgets for traditional AI are estimated to be $70 billion. |
# | Cloud Software Spend | Enterprise budgets for cloud software are estimated to be $400 billion. |
# | AI Adoption | The number of enterprises using some form of AI ticked up 7% (from 48% in 2022 to 55% in 2023). |
# | AI Spend Growth | AI spend within enterprises grew by an average of 8%. |
# | Total Enterprise Tech Spend | Enterprise budgets for AI and cloud software only grew by 5%. |

# %%
# prompt: convert from previous prompt output ("result") to data frame Table

import pandas as pd
df = pd.read_csv(io.StringIO(result), sep="|")
df
# Out:
#    Unnamed: 0              Enterprise Spend   \
# 0         NaN                      AI Spend
# 1         NaN          Traditional AI Spend
# 2         NaN          Cloud Software Spend
# 3         NaN                   AI Adoption
# 4         NaN               AI Spend Growth
# 5         NaN   Total Enterprise Tech Spend
#
#    AI is still surprisingly small compared to other software categories. Most of the value that will be created remains to be seen.   \
# 0   Enterprise investment in generative AI is est...
# 1   Enterprise budgets for traditional AI are est...
# 2   Enterprise budgets for cloud software are est...
# 3   The number of enterprises using some form of ...
# 4   AI spend within enterprises grew by an averag...
# 5   Enterprise budgets for AI and cloud software ...
#
#    Unnamed: 3
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
